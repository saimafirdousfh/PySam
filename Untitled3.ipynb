# %%
# !pip install diffusers transformers gradio accelerator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 MB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
import torch

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.6.0+cu124
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, fastai, peft, sentence-transformers, timm, torchaudio, torchvision

# %%
model_id1 = "dreamlike-art/dreamlike-diffusion-1.0"
model_id2 = "stabilityai/stable-diffusion-xl-base-1.0"

pipe = StableDiffusionPipeline.from_pretrained(model_id1, torch_dtype=torch.float16, use_safetensors=True)
pipe = pipe.to("cuda")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/511 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/341 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/518 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# ...

# %%
prompt = """Aestronaut walking on pink flower garden
"""

# %%
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
print("[PROMPT]: ",prompt)
plt.imshow(image);
plt.axis('off');
# Out:
# [PROMPT]:  Aestronaut walking on pink flower garden

# %%
prompt2 = """Aesthetic table with expensive dishes and surrounded by chair and a girl with blonde hair sitting on one of the chair
"""

image = pipe(prompt2).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print('[PROMPT]: ',prompt2)
plt.imshow(image);
plt.axis('off');
# Out:
# [PROMPT]:  Aesthetic table with expensive dishes and surrounded by chair and a girl with blonde hair sitting on one of the chair

# %%
def generate_image(pipe, prompt, params):
  img = pipe(prompt, **params).images

  num_images = len(img)
  if num_images>1:
    fig, ax = plt.subplots(nrows=1, ncols=num_images)
    for i in range(num_images):
      ax[i].imshow(img[i]);
      ax[i].axis('off');

  else:
    fig = plt.figure()
    plt.imshow(img[0]);
    plt.axis('off');
  plt.tight_layout()

# %%
prompt = "dreamlike, beautiful girl playing the festival of colors, draped in traditional Indian attire, throwing colors"

params = {}

# %%
generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
#num inference steps
params = {'num_inference_steps': 100}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#height width
params = {'num_inference_steps': 100, 'width': 512, 'height': int(1.5*640)}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#height width
params = {'num_inference_steps': 100, 'width': 512, 'height': int(1.5*640)}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
#num_images_per_prompt
params = {'num_inference_steps': 100, 'num_images_per_prompt': 2}

generate_image(pipe, prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
prompt4 = {"futuristic cityscape at sunset, with skyscrapers reflecting vibrant orange and pink hues, flying cars, and neon signs illuminating the streets"}
params = {}

# %%
generate_image(pipe, prompt4, params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-166206a46c07> in <cell line: 0>()
# ----> 1 generate_image(pipe, prompt4, params)
#
# <ipython-input-14-72613620f794> in generate_image(pipe, prompt, params)
#       1 def generate_image(pipe, prompt, params):
# ----> 2   img = pipe(prompt, **params).images
#       3
#       4   num_images = len(img)
#       5   if num_images>1:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
prompt4 = "futuristic cityscape at sunset, with skyscrapers reflecting vibrant orange and pink hues, flying cars, and neon signs illuminating the streets"
params = {
    "height": 512,     # Image height
    "width": 512,      # Image width
    "num_inference_steps": 50,  # Number of diffusion steps
    "guidance_scale": 7.5,      # Classifier-free guidance scale
}
image = pipe(prompt4, **params).images[0]
image.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
generate_image(pipe,prompt4,params)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
prompt5 = " A majestic castle on a mountain peak surrounded by clouds and waterfalls"
params = {
    "height": 768,     # Image height
    "width": 768,      # Image width
    "num_inference_steps": 130,  # Number of diffusion steps
    "guidance_scale": 10,      # Classifier-free guidance scale
}
#image = pipe(prompt5, **params).images[0]
generate_image(pipe,prompt5,params)
# Out:
#   0%|          | 0/130 [00:00<?, ?it/s]

# %%
prompt5 = " A majestic castle on a mountain peak surrounded by clouds and waterfalls"
params = {
    "height": 800,     # Image height
    "width": 800,      # Image width
    "num_inference_steps": 150,  # Number of diffusion steps
    "guidance_scale": 10,      # Classifier-free guidance scale
}
#image = pipe(prompt5, **params).images[0]
generate_image(pipe,prompt5,params)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]

# %%
prompt6 = "A tiger prowling through dense jungle with beams of sunlight breaking through"
params = {
    "height": 776,     # Image height
    "width": 776,      # Image width
    "num_inference_steps": 150,  # Number of diffusion steps
    "guidance_scale": 10,      # Classifier-free guidance scale
}
#image = pipe(prompt5, **params).images[0]
generate_image(pipe,prompt6,params)
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
